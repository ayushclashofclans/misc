# %%
import numpy as np
import pandas as pd

# %%
holdings={'infy':22.84,'hcl':8.65,'tcs':7.70,'techmah':6.81,'persistent':4.17,'wipro':3.27,'coforge':3.21,
          'mindtree':2.73,'cyient':2.51,'irctc':2.48,'airtel':2.10,'kpit':1.86,'landttech':1.85,'firstsource':1.75,
          'landtinfotech':1.75,'birlasoft':1.68,'eclerx':1.65,'justdial':1.62,'mphasis':1.58,'indiamart':1.53,
          'teamlease':1.48,'niit':1.09,'microsoftcorp':0.97
         }

# %%
holdings
# Out:
# {'infy': 22.84,
#  'hcl': 8.65,
#  'tcs': 7.7,
#  'techmah': 6.81,
#  'persistent': 4.17,
#  'wipro': 3.27,
#  'coforge': 3.21,
#  'mindtree': 2.73,
#  'cyient': 2.51,
#  'irctc': 2.48,
#  'airtel': 2.1,
#  'kpit': 1.86,
#  'landttech': 1.85,
#  'firstsource': 1.75,
#  'landtinfotech': 1.75,
#  'birlasoft': 1.68,
#  'eclerx': 1.65,
#  'justdial': 1.62,
#  'mphasis': 1.58,
#  'indiamart': 1.53,
#  'teamlease': 1.48,
#  'niit': 1.09,
#  'microsoftcorp': 0.97}

# %%
x=10000
key=[]
holding=[]
for i in holdings.keys():
    key.append(i)
    holding.append(holdings[i])
currprice=[1446.90,983.35,3273.80,1073,2520.25,818.20,554.30,3978.95,540.85,0,243.30,0,0,163.10,7267.50,2009.75,402.40,966.55,0,4173.85,0,3627.25,]

# %%
df=pd.DataFrame(index=key)
df['Holding %'] = holding
df['money to invest']=x*df['Holding %']/100
df['current price']=currprice
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-a2682f113a7f> in <module>
#       2 df['Holding %'] = holding
#       3 df['money to invest']=x*df['Holding %']/100
# ----> 4 df['current price']=currprice
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3161         else:
#    3162             # set column
# -> 3163             self._set_item(key, value)
#    3164
#    3165     def _setitem_slice(self, key: slice, value):
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3240         """
#    3241         self._ensure_valid_index(value)
# -> 3242         value = self._sanitize_column(key, value)
#    3243         NDFrame._set_item(self, key, value)
#    3244
#
# ...

# %%
df
# Out:
#                Holding %  money to invest
# infy               22.84           2284.0
# hcl                 8.65            865.0
# tcs                 7.70            770.0
# techmah             6.81            681.0
# persistent          4.17            417.0
# wipro               3.27            327.0
# coforge             3.21            321.0
# mindtree            2.73            273.0
# cyient              2.51            251.0
# irctc               2.48            248.0
# airtel              2.10            210.0
# kpit                1.86            186.0
# landttech           1.85            185.0
# firstsource         1.75            175.0
# landtinfotech       1.75            175.0
# birlasoft           1.68            168.0
# eclerx              1.65            165.0
# justdial            1.62            162.0
# mphasis             1.58            158.0
# indiamart           1.53            153.0
# teamlease           1.48            148.0
# ...

# %%
df['Holding %'].sum()
# Out:
# 85.28000000000002

# %%
df.sum()
# Out:
# Holding %            85.28
# money to invest    8528.00
# dtype: float64

# %%
df
# Out:
#                Holding %  money to invest
# infy               22.84           2284.0
# hcl                 8.65            865.0
# tcs                 7.70            770.0
# techmah             6.81            681.0
# persistent          4.17            417.0
# wipro               3.27            327.0
# coforge             3.21            321.0
# mindtree            2.73            273.0
# cyient              2.51            251.0
# irctc               2.48            248.0
# airtel              2.10            210.0
# kpit                1.86            186.0
# landttech           1.85            185.0
# firstsource         1.75            175.0
# landtinfotech       1.75            175.0
# birlasoft           1.68            168.0
# eclerx              1.65            165.0
# justdial            1.62            162.0
# mphasis             1.58            158.0
# indiamart           1.53            153.0
# teamlease           1.48            148.0
# ...
